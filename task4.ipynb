# %% [markdown]
# # <a id="#">Task 4 – Edge detection: Derivative operators</a>

# %%
import numpy
import matplotlib.pyplot as plt

# %% [markdown]
# ---
#
# ## Prewitt filters
#
# **<a id="#">Task 4.1.1.</a>** Load the image `data/lena.png` and show it:

# %%
img = plt.imread('data/lena.png')
plt.figure(figsize=(15,8))
plt.imshow(img, 'gray')
plt.colorbar()

# %% [markdown]
# **<a id="#">Task 4.1.2.</a>** Implement horizontal and vertical $3 \times 3$ Prewitt filters:

# %%
def prewitt_h(img, size): #size=3
    # write your code here
    result = numpy.zeros(img.shape)
    n = (size - 1) // 2 #nn=1
    h_filter = numpy.array([[-1,0,1], [-1,0,1], [-1,0,1]], #numpy.int32) #Filter muss geflippt werden
    #for p in numpy.ndindex(img.shape):
    #numpy.add() #zum Tupel addieren
    for p in numpy.ndindex(img.shape):
        if p[0]>=n and p[0]<img.shape[0]-n and p[1]>=n and p[1]<img.shape[1]-n:
        neighborhood_sum = 0
            for q in numpy.ndindex(size, size):
                intensity = img[(p[0]+ q[0]-n), p[1]+ q[1]-n)]
                neighborhood_sum +=(h_filter[q[0], q[1]*intensity])
            result [p[0],p[1] = neighborhood_sum/(size**2)]
    return result 
            # write your code here
           # if p[0]>=n and p[0]<img.shape[0]-n: 
             #   if q[0]==0:
              #      neighborhood_sum += img[(p[0]+ q[0]-n)]
              #  elif q[0]==1:
              #      neighborhood_sum += img[(p[0]+ q[0]-n)]*0
              #  elif q[0]==2:
              #      neighborhood_sum += img[(p[0]+ q[0]-n)]*(-1)
              #  result[p] = neighborhood_sum*(1/6)
            #else: 
             #   result[p]=0    

    #return result
# Out:
#   File <tokenize>:14
#     result [p[0],p[1] = neighborhood_sum/(size**2)]
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
import numpy as np

def prewitt_h(img, size):
    result = np.zeros_like(img)
    n = (size - 1) // 2

    for p in np.ndindex(img.shape[0]):
        neighborhood_sum = 0

        for q in np.ndindex(size, size):
            if p[0] + q[0] - n >= 0 and p[0] + q[0] - n < img.shape[0]:
                neighborhood_sum += img[p[0] + q[0] - n, p[1]] * (q[0] - n)

        result[p] = neighborhood_sum * (1 / 6) if 0 <= p[0] < img.shape[0] else 0

    return result

# %%
lena_prewitt_h = img.copy()
plt.imshow(prewitt_h(lena_prewitt_h,3))
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 lena_prewitt_h = img.copy()
# ----> 2 plt.imshow(prewitt_h(lena_prewitt_h,3))
#       3 plt.colorbar()
#
# Cell In[40], line 12, in prewitt_h(img, size)
#      10     for q in np.ndindex(size, size):
#      11         if p[0] + q[0] - n >= 0 and p[0] + q[0] - n < img.shape[0]:
# ---> 12             neighborhood_sum += img[p[0] + q[0] - n, p[1]] * (q[0] - n)
#      14     result[p] = neighborhood_sum * (1 / 6) if 0 <= p[0] < img.shape[0] else 0
#      16 return result
#
# IndexError: tuple index out of range

# %%
def prewitt_v(img, size):
    # write your code here
    result = numpy.zeros(img.shape)
    n = (size - 1) // 2
    for p in numpy.ndindex(img.shape):
        neighborhood_sum = 0
        for q in numpy.ndindex(size, size):
            # write your code here
            if p[1]>=n and p[1]<img.shape[1]-n: 
                if q[1]==0:
                    neighborhood_sum += img[(p[1]+ q[1]-n)]
                elif q[1]==1:
                    neighborhood_sum += img[(p[1]+ q[1]-n)]*0
                elif q[1]==2:
                    neighborhood_sum += img[(p[1]+ q[1]-n)]*(-1)
                result[p] = neighborhood_sum*(1/6)
            else: 
                result[p]=0    

    return result

# %%
lena_prewitt_v = img.copy()
plt.imshow(prewitt_v(lena_prewitt_v,3))
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 lena_prewitt_v = img.copy()
# ----> 2 plt.imshow(prewitt_v(lena_prewitt_v,3))
#       3 plt.colorbar()
#
# Cell In[29], line 9, in prewitt_v(img, size)
#       6 neighborhood_sum = 0
#       7 for q in numpy.ndindex(size, size):
#       8     # write your code here
# ----> 9     if p[1]>=n and p[1]<img.shape[1]-n:
#      10         if q[1]==0:
#      11             neighborhood_sum += img[(p[1]+ q[1]-n)]
#
# IndexError: tuple index out of range

# %% [markdown]
# **<a id="#">Task 4.1.3.</a>** Test your above solution using the functions `prewitt_h` and `prewitt_v` for the previously loaded image and show the result:

# %% [markdown]
# **<a id="#">Task 4.1.4.</a>** Compare your results with the correct result image `data/lena_prewitt_h.tiff` and `data/lena_prewitt_v.tiff`:

# %%
import skimage.io
img_prewitt_h = skimage.io.imread('data/lena_prewitt_h.tiff')
skimage.io.imshow(img_prewitt_h)

# %% [markdown]
# ---
#
# ## Edge detection
#
# **<a id="#">Task 4.2.1.</a>** Use your results from **Task 4.1.2 – 4.1.3** to compute the *gradient magnitude* of the image:

# %%
#vertical + horizontal kombinieren
#prewitt h und v als variable

# %% [markdown]
# **<a id="#">Task 4.2.2.</a>** Compare your result with the correct result image `data/lena_prewitt_gradmag.tiff`:

# %% [markdown]
# ---
#
# ## Sobel filters (bonus)
#
# **<a id="#">Task 4.3.1.</a>** Implement the two functions `sobel_h` and `sobel_v` for horizontal and vertical $3 \times 3$ Sobel filtering, respectively:

# %% [markdown]
# **<a id="#">Task 4.3.2.</a>** Test your above solution using the functions `sobel_h` and `sobel_v` for the previously loaded image and show the result:

# %% [markdown]
# **<a id="#">Task 4.3.3.</a>** Compare your results with the correct result image `data/lena_sobel_h.tiff` and `data/lena_sobel_v.tiff`:
